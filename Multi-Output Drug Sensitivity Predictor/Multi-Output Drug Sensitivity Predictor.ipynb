# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/naimdotcom/Machine-Learning/main/data/GDSC2_fitted_dose_response_27Oct23 - Sheet1.csv")

# %%
df.sample()
# Out:
#       DATASET  NLME_RESULT_ID  NLME_CURVE_ID CELL_LINE_NAME SANGER_MODEL_ID  \
# 42130   GDSC2             343       15976250      EPLC-272H       SIDM01044
#
#                CANCER_TYPE  DRUG_ID DRUG_NAME PUTATIVE_TARGET  \
# 42130  Other Solid Cancers     1061  SB590885            BRAF
#
#              PATHWAY_NAME  MIN_CONC  MAX_CONC   LN_IC50       AUC      RMSE  \
# 42130  ERK MAPK signaling  0.005003       5.0  3.979706  0.962142  0.026627
#
#         Z_SCORE
# 42130 -0.262779

# %%
pivot_df = df.pivot_table(index=['CELL_LINE_NAME', 'CANCER_TYPE'], 
                          columns='DRUG_NAME', 
                          values='LN_IC50')

# %%
selected_cols = ['Camptothecin', 'Cisplatin', 'Gemcitabine', 'Paclitaxel']
features = ['Camptothecin', 'Oxaliplatin']
targets = ['Docetaxel', '5-Fluorouracil', 'Palbociclib']

clear_df = pivot_df[selected_cols].dropna()

# %%
input_label = []
output_labe = ["LN_IC50", "AUC"]
